# %%
# %matplotlib inline
from sklearn.externals import joblib
from keras.models import load_model
import numpy as np
from sklearn.preprocessing import StandardScaler
import keras
from keras import models
from keras import layers
import librosa
import os
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (13, 5)
plt.rcParams['figure.figsize'] = (14, 5)
from IPython.display import Audio
from song import drum
# Out:
# Using TensorFlow backend.

# %%
scaler = joblib.load(os.path.abspath("scaler.save"))
model = load_model('drum_model.h5')
# Out:
# WARNING:tensorflow:From c:\users\p\pycharmprojects\2019-ca400-ferryp2\project\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\p\pycharmprojects\2019-ca400-ferryp2\project\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
y, sr = librosa.load("../Songs/drumbeat1.wav")
y = y[:sr*30]

# %%
Audio(y, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
onset_env = librosa.onset.onset_strength(y)
onset_frames = librosa.onset.onset_detect(y, onset_envelope=onset_env)
onset_samples = onset_frames * 512

# %%
plt.plot(onset_env)
for on in onset_frames:
    plt.axvline(x=on)
plt.show()

# %%
from scipy.signal import get_window
window = get_window("hamming", 5000)

# %%
segments = []
for ons in onset_samples[:-1]:
    segment = y[ons-3000:ons + 3000]
#     windowed = segment * window
    segments.append(segment)

# %%
Audio(segments[0], rate=sr)

# %%
Audio(windowed, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34132c520a89> in <module>
# ----> 1 Audio(windowed, rate=sr)
#
# NameError: name 'windowed' is not defined

# %%
for i in range(len(segments)):
    segments[i] = drum.extract_feats(segments[i], sr)
trans = scaler.transform(np.array(segments))

# %%
predictions = (model.predict_proba(trans))

# %%
len(predictions)
classes = []
for prediction in predictions:
#     print(predict)
#     highs =(np.argsort(prediction[prediction > .0]))
#     highest = (c[np.argmax(prediction)])
#     classes.append([c[x] for x in highs] )
    classes.append(c[np.argmax(prediction)])

# %%
classes
# Out:
# ['Kick',
#  'OpenHat',
#  'OpenHat',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Kick',
#  'ClosedHat',
#  'ClosedHat',
#  'Kick',
#  'Kick',
#  'Kick',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'ClosedHat',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Kick',
#  'Snare',
#  'Kick',
#  'Kick',
#  'Snare',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Kick',
#  'Snare',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Kick',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Kick',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Kick',
#  'Snare',
#  'Snare',
#  'Kick',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'Kick',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Tom',
#  'Snare',
#  'Kick',
#  'Snare',
#  'Kick',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'Kick',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'ClosedHat',
#  'Kick',
#  'Snare',
#  'ClosedHat',
#  'ClosedHat',
#  'ClosedHat',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Snare',
#  'Kick',
#  'Snare',
#  'Snare']

# %%
c = {0: "Clap",
     1: "ClosedHat",
     2: "Crash",
     3: "Kick",
     4: "OpenHat",
     5: "Ride",
     6: "Snare",
     7: "Tom"}

# %%
plt.plot(p[0])
plt.xticks(np.arange(0,8), labels=t)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-91719bd7c71d> in <module>
# ----> 1 plt.plot(p[0])
#       2 plt.xticks(np.arange(0,8), labels=t)
#       3 plt.show()
#
# NameError: name 'p' is not defined

# %%
t = tuple(list(c.values()))

# %%
plt.plot(np.log10(p[0]))
plt.show()
# Out:
# c:\users\p\pycharmprojects\2019-ca400-ferryp2\project\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
from song import midi_tools

# %%
bpm = librosa.beat.tempo(y)[0]

# %%
bpm
# Out:
# 99.38401442307692

# %%
newclasses = [[x] for x in classes]

# %%
midi_tools.out_midi_drums(onset_frames, newclasses, bpm, sr)

# %%
newclasses
# Out:
# [['Kick'],
#  ['OpenHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Kick'],
#  ['Snare'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['Kick'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['Kick'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Tom'],
#  ['Kick'],
#  ['Snare'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['ClosedHat'],
#  ['Kick'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['ClosedHat'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Snare'],
#  ['Kick'],
#  ['Kick']]
